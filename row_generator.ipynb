# %% [markdown]
# Importing libraries

# %%
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
import csv

# %%
names = ["dennis","justin","kenneth","kenneth_brille","liza","liza_brille","miriam", 
         "steffen", "adham", "vincent"]
root = os.getcwd()
image_folder = r"D:\daisy_dataset\image"
faces_folder = r"D:\daisy_dataset\face"

# %% [markdown]
# Label mapping

# %%
# Code to obtain label mapping
names_dict = {}
for id,name in enumerate(names):
    names_dict[id] = name

print(names_dict)

# %% [markdown]
# Creating dataframe by row

# %%
def row_generator(folder_list,names_dict):

    for folder in folder_list:
        for id,name in names_dict.items():
            sub_dir = os.path.join(folder,name)
            if os.path.exists(sub_dir):
                for filename in os.listdir(sub_dir):
                    file_path = os.path.join(sub_dir,filename)
                    yield file_path,id

row_gen = row_generator([faces_folder],names_dict)

image_counter = 0
try:
    while True:
        # Attempt to get the next item
        next_item = next(row_gen)
        image_counter += 1
        #print(next_item)
except StopIteration:
    print(f"End of iterator reached with {image_counter} images.")
# Out:
# End of iterator reached with 9620 images.

# %% [markdown]
# Creating dataframe by column

# %%
# Specify the path of the CSV file
# csv_file_path = os.path.join(root, 'datasets/label.csv')
csv_file_path = os.path.join(r'D:\daisy_dataset', 'face_label.csv')

# Open the CSV file in write mode
with open(csv_file_path, 'w', newline='') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header to the CSV file
    csv_writer.writerow(['filepath', 'label'])

    # Iterate over the rows generated by 'row_generator'
    row_gen = row_generator([faces_folder], names_dict)
    for item in tqdm(row_gen):
        # Write each row to the CSV file
        csv_writer.writerow([item[0], item[1]])
# Out:
# 0it [00:00, ?it/s]
# 4810it [00:00, 51385.86it/s]
